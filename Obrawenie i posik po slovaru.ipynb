# %%
person_dict = { 
    'person_id': [417283, 849734, 132223, 573943, 19475, 3294095],  
    'person_name': ['Keanu Reeves', 'Jim Carrey', 'Johnny Depp', 'Keira Knightley', 'Natalie Portman', 'Marion Cotillard']
}
travel_log = { 
    'travel_id': [101, 102, 105, 121, 145, 161, 178], 
    'person_id': [573943, 132223, 849734, 417283, 382043, 3294095, 417283], 
    'country': ['Russia', 'Australia', 'Turkey', 'Japan', 'China', 'USA', 'Mexico'],
    'price': [5900, 15330, 10200, 12990, 9890, 13500, 7400], 
    'real_cost': [3500, 10280, 7600, 9850, 4340, 11200, 3300]
}
person = input()
#Poluchaem ID dl9 sravneni9
#obratilsa k person_id, peredal vo vtorie kvadratnir skobki poziciu iz masiva person_name
id_klienta = person_dict['person_id'][person_dict['person_name'].index(person)]
# cherez count poluchili chislo povtorov ID
kol_vo_poezdok = travel_log['person_id'].count(id_klienta)
if kol_vo_poezdok > 1:
  print("Several")
if kol_vo_poezdok == 1:
# poluchili nomer id v travel_log chtobi sootnesti so stranoi
  id_strani = travel_log['person_id'].index(id_klienta)
  print(travel_log['country'][id_strani])
else:
  print("None")
# Out:
# Marion Cotillard
# USA
