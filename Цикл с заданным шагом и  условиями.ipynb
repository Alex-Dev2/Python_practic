# %%
health = 100
sec = 0
n = input()
if n == "Киборг":
  for i in range(health, 0, -10):
    sec += 1
if n == "Робот-приспешник":
  for i in range(health, 0, -7):
    sec += 1
if n == "Инопланетный захватчик":
  for i in range(health, 0, -28):
    sec += 1
print(sec)
# 2var

a = input()


def prt(hp, gr, t):
    while not hp <= 0:
        hp -= t
        gr = gr + 1
    print(gr)


if a == "Киборг":
    prt(100, 0, 10)
elif a == "Робот-приспешник":
    prt(100, 0, 7)
elif a == "Инопланетный захватчик":
    prt(100, 0, 28)
else:
    print("Введите точное имя врага")
# 3var
import math
a=input()
Damage={'Киборг': 5,'Робот-приспешник': 7,'Инопланетный захватчик': 14}  
time={'Киборг':2 ,'Робот-приспешник': 1,'Инопланетный захватчик':0.5 }

hero_hp=100
all_time=(math.ceil(hero_hp/Damage[a])*time[a])
print(int(all_time))
# Out:
# Киборг
# 10
