# %%
for i in input():
    if i in 'УЕЫАОЭЯИЮЁуеыаоэяиюё':
        print(i)
# vtoroi variant
glas = 'а,у,о,ы,э,я,ю,ё,и,е'
glas = glas + glas.upper()
word = input()
for i in word:
	if i in glas:
		print(i)
# Out:
# АотдляатыЦУЕЩКЦГЕР
# А
# о
# я
# а
# ы
# У
# Е
# Е
